# %% [markdown]
# ## Git & Github Configuration

# %% [markdown]
# This is a tutorial on how use and configure github from zero

# %% [markdown]
# The are multiple ways on how github can work on you local PC. For this, we need git. Get the git scm for Windows, Mac or linux, that can be found on: https://git-scm.com/downloads
#
# After downloading and installing, then, run the **git bash** from the start menu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *git bash* uses commands to control both local repository and remote repositories, such as github. For the first part, we will work on how to set and interact with our local repository.
#
# To start, we open the *git bash* and navigate to a folder where we will use git to control our files. In this case, we navigate to *~/Documents/Github/Datascience1* folder:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Then, it is needed to initialize our local git repository and set our username, for this, do:

# %% [raw]
# # This initializes git and makes the folder a git repository, so it is tracked by git
# git init
#
# # This is to check the status of the git
# git status
#
# # This configures the global name as crcoronado; this is NOT the same GITHUB user, but a user to define the commits and push to the platform
# git config --global user.name crcoronado

# %% [markdown]
# At this moment, we can create new files or clone (download) an existing repositiory from github, do:

# %% [raw]
# git clone https://github.com/crcoronado/Datascience1.git # The address is found on the page of your githhub account

# %% [markdown]
# This will directly clone from github into your computer the files of the repository from the cloud.

# %% [markdown]
# In the case we are creating the files, lets assume we have a Jupyter notebook in the folder, that we are working currently at this moment, for example:
# ![image.png](attachment:image.png)

# %% [markdown]
# After we have created and add some content to our file, we will want to add this file into our repository and save the changes we have made so far. This is calles *staging area* that is our local repository.
#
# To add the files we want into our local repository, we do:

# %% [raw]
# # git add <filename>
# git add ActividadClase_1.ipynb
#
# # Let's check the status of the git at this moment
# git status

# %% [markdown]
# ![image.png](attachment:image.png)
#
# At this moment we have added the file but we have not commited (or saved) the changes into our *staging area*. For this, we for this, we do:

# %% [raw]
# # Commiting the changes into our staging area, adding a message for our commit for the description
# git commit -m "Added the file with the initial comments"

# %% [markdown]
# ![image.png](attachment:image.png)
#
# We can see that the file (or files) have been added to the master branch, with the respective changes. Now, lets just check the status of git
#
# ![image-2.png](attachment:image-2.png)
#
# To speed up, instead of adding each file, if you want to add all the files in the folder to the *staging area*, you do:

# %% [raw]
# #Add all files to the staging area
# git add .

# %% [markdown]
# Lets now set our authentication to our github / remote repository:

# %% [raw]
# # Set Global Username
# git config --global user.name "crcoronado"
#
# # Email used at github
# git config --global user.email "crcoronado@hotmail.com"

# %% [markdown]
# Now, let's try to push our local files into our remote repository. To do this, use the code:

# %% [raw]
# #We create the main branch
# git branch -M main
#
# #git remote add origin <Github_URL_Address>, This is to create a new Repository if it has not been created before at Github
# git remote add origin https://github.com/crcoronado/Datascience1.git
#
# #If the repository is already created in Github, then do: git remote set-url origin <GitHub_URL_Address>
# git remote set-url origin https://github.com/crcoronado/Datascience1.git
#
# #Now, lets push our local files to the remote repository at Github
# git push -u origin
# git push -u origin master

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The, after setting our local repository URL, we will *push*  the files into githib. The first time we try this, it will request us to log in with our account of github through a web browser, as it is seen below:
#
# ![image-2.png](attachment:image-2.png)
#
# Finally, we Authorize the Git Credential Manager to access to the remote repository, using our password
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# Then, we can see at the *git scm* that our push was successful:
#
# ![image-5.png](attachment:image-5.png)
#
# Also, we can access directly the GitHub page, where we will see the file we pushed from our local repository:
#
# ![image-6.png](attachment:image-6.png)
#
# Now, let's assume we make some changes into our file, so again, we push them to the remote repository again with push. At this moment is enough to do *git push* because with the previous command *-u origin* we already established the *--set-upstream*, that gives the reference of the origin.

# %% [raw]
# # We add all the files in our folder into our staging area
# git add .
#
# #Then we commit the changes with a message
# got commit -m "Added a Test Message"
#
# #Finally, we push the changes to Github
# git push

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Now, lets say that someone edited the file and pushed it to github:
#
# ![image-2.png](attachment:image-2.png)
#
# To get the file updated in our local repository, we do a git pull as follows:
#
# ![image-3.png](attachment:image-3.png)
#
# If we reopen the file in Jupyter, we will see the changes:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Now, if we want to download a repository that already exists in a remote repository like GitHub, we do a clone from the main it folder in our PC, for example, from */Documents/35 Github*

# %% [raw]
# #Clone an already created repository into your local repository
# git clone https://github.con/crcoronado/github-initial-configuration.git
