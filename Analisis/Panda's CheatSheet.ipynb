# %% [markdown]
# # Panda's & NumPy Long Cheat Sheet
# This is a Pandas Cheat Sheet on how to use Panda's Library
#
# ### Pandas
#
# "The Python library to do the mathematical operations in a flexible manner is called Pandas library. This is an open source library used in data analysis and also in data manipulation so that data scientists can retrieve information from the data. It has BSD license and the number tables are manipulated easily. It is written in Python, Cython and C language. It is an open source software and has high performance when compared with other libraries. The library provides tables and not arrays for the memory retrieval. The data structures are easy to use."
# https://www.educba.com/what-is-pandas/
#
# ![image.png](attachment:image.png)
#
# ### NumPy
#
# "NumPy is the fundamental package for scientific computing in Python. It is a Python library that provides a multidimensional array object, various derived objects (such as masked arrays and matrices), and an assortment of routines for fast operations on arrays, including mathematical, logical, shape manipulation, sorting, selecting, I/O, discrete Fourier transforms, basic linear algebra, basic statistical operations, random simulation and much more." https://numpy.org/doc/stable/user/whatisnumpy.html
#
# <a id='101'></a>
# ### Commands [↓](#1)

# %%
#Installing Pandas. Use ! to run it under Jupyter Notebook
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ccoronad\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\ccoronad\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ccoronad\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\ccoronad\anaconda3\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\ccoronad\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Check pandas and numpy version
print("Pandas version is " + pd.__version__)
print("NumPy version is " + np.__version__)
# Out:
# Pandas version is 1.0.5
# NumPy version is 1.18.5

# %%
# Load the Dataframe File
dataframe = pd.read_csv("winemag-data-130k-v2.csv")

# %%
# Show the Headers and number of lines defined 
dataframe.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
# Shows the last lines of the dataframe
dataframe.tail(3)
# Out:
#         Unnamed: 0 country                                        description  \
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province region_1  \
# 129968                          Kritt      90   30.0   Alsace   Alsace
# 129969                            NaN      90   32.0   Alsace   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace   Alsace
#
#        region_2 taster_name taster_twitter_handle  \
# 129968      NaN  Roger Voss            @vossroger
# 129969      NaN  Roger Voss            @vossroger
# 129970      NaN  Roger Voss            @vossroger
#
#                                                     title         variety  \
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 129968       Domaine Gresser
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit

# %%
# Show the general info of the dataframe, with the type for each column
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %%
# Show directly the Dataframe Column Type
dataframe.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
# Number of Index (Rows) and Columns of the dataframe
dataframe.shape
# Out:
# (129971, 14)

# %%
# Shows the number of index (rows) of the dataframe
dataframe.index
# Out:
# RangeIndex(start=0, stop=129971, step=1)

# %%
# Shows the number of columns of the dataset
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# Shows the type of the object, for example, it is a series, a dataframe, etc.
print("The type of the object 'Winery' is: " + str(type(dataframe.winery)))
print("The type of the object 'dataframe' is: " + str(type(dataframe)))
# Out:
# The type of the object 'Winery' is: <class 'pandas.core.series.Series'>
# The type of the object 'dataframe' is: <class 'pandas.core.frame.DataFrame'>

# %%
# Statistical Sumamry of the Dataframe (columns with int/float type values)
dataframe.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
# Summary of the Object Columns
dataframe.describe(include = ['O'])
# Out:
#        country                                        description designation  \
# count   129908                                             129971       92506
# unique      43                                             119955       37979
# top         US  This zesty red has pretty aromas that suggest ...     Reserve
# freq     54504                                                  3        2009
#
#           province     region_1       region_2 taster_name  \
# count       129908       108724          50511      103727
# unique         425         1229             17          19
# top     California  Napa Valley  Central Coast  Roger Voss
# freq         36247         4480          11065       25514
#
#        taster_twitter_handle  \
# count                  98758
# unique                    15
# top               @vossroger
# freq                   25514
#
#                                                     title     variety  \
# count                                              129971      129970
# unique                                             118840         707
# top     Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma...  Pinot Noir
# freq                                                   11       13272
#
#                     winery
# count               129971
# unique               16757
# top     Wines & Winemakers
# freq                   222

# %%
# Shows the counter of the values in a Header
dataframe['country'].value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Macedonia                    12
# Serbia                       12
# Czech Republic               12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Armenia                       2
# Bosnia and Herzegovina        2
# Slovakia                      1
# China                         1
# Egypt                         1
# Name: country, dtype: int64

# %%
# Shows all the values in the Column, including empty values
dataframe['country'].value_counts(dropna=False)
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# NaN                          63
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Macedonia                    12
# Serbia                       12
# Czech Republic               12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Armenia                       2
# Bosnia and Herzegovina        2
# Egypt                         1
# Slovakia                      1
# China                         1
# Name: country, dtype: int64

# %%
# Show the summary of null values in each column
dataframe.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
# Shows unique values per column not including null values
dataframe.nunique()
# Out:
# Unnamed: 0               129971
# country                      43
# description              119955
# designation               37979
# points                       21
# price                       390
# province                    425
# region_1                   1229
# region_2                     17
# taster_name                  19
# taster_twitter_handle        15
# title                    118840
# variety                     707
# winery                    16757
# dtype: int64

# %%
# Shows unique values per column including null values
dataframe.nunique(dropna=False)
# Out:
# Unnamed: 0               129971
# country                      44
# description              119955
# designation               37980
# points                       21
# price                       391
# province                    426
# region_1                   1230
# region_2                     18
# taster_name                  20
# taster_twitter_handle        16
# title                    118840
# variety                     708
# winery                    16757
# dtype: int64

# %%
# Shows the count of all non-null values
dataframe.count()
# Out:
# Unnamed: 0               129971
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
# Shows the unique values in the column
dataframe['country'].unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
# Renames a Header in the Dataframe
dataframe = dataframe.rename(columns={'taster_twitter_handle':'taster_twitter'})

# %% [markdown]
# <a id='102'></a>
# ### Indexers loc and iloc (implicit loc, by using number index rather than Header's names) [↓](#2)
# These are used to index and segment the information of the table

# %%
# Show the table between the rows 1 to 5, and between columns 'points' to taster_name
dataframe.loc[1:5, 'points': 'taster_name']
# Out:
#    points  price        province             region_1           region_2  \
# 1      87   15.0           Douro                  NaN                NaN
# 2      87   14.0          Oregon    Willamette Valley  Willamette Valley
# 3      87   13.0        Michigan  Lake Michigan Shore                NaN
# 4      87   65.0          Oregon    Willamette Valley  Willamette Valley
# 5      87   15.0  Northern Spain              Navarra                NaN
#
#           taster_name
# 1          Roger Voss
# 2        Paul Gregutt
# 3  Alexander Peartree
# 4        Paul Gregutt
# 5   Michael Schachner

# %%
# Same table but using iloc (using numbers rather than header's names), 
# the range number of the header's numbers will go up to n-1 as df.iloc[a:b , m:n]
dataframe.iloc[1:5, 4:10]
# Out:
#    points  price  province             region_1           region_2  \
# 1      87   15.0     Douro                  NaN                NaN
# 2      87   14.0    Oregon    Willamette Valley  Willamette Valley
# 3      87   13.0  Michigan  Lake Michigan Shore                NaN
# 4      87   65.0    Oregon    Willamette Valley  Willamette Valley
#
#           taster_name
# 1          Roger Voss
# 2        Paul Gregutt
# 3  Alexander Peartree
# 4        Paul Gregutt

# %% [markdown]
# <a id='103'></a>
# ### Data Selection [↓](#3)

# %%
# Detailed Data Selection with any desired arrange, as df[['Header_1','Header_3',...,'Header_X']] [ initial_row : final_row-1 ]
dataframe[['country', 'taster_name', 'points']][1:10]
# Out:
#     country         taster_name  points
# 1  Portugal          Roger Voss      87
# 2        US        Paul Gregutt      87
# 3        US  Alexander Peartree      87
# 4        US        Paul Gregutt      87
# 5     Spain   Michael Schachner      87
# 6     Italy       Kerin O’Keefe      87
# 7    France          Roger Voss      87
# 8   Germany  Anna Lee C. Iijima      87
# 9    France          Roger Voss      87

# %%
# Applying Filters into the Selection, this can be done by adding basic operators between parenthesis
# In this case, it will show the first 9 values (1 to n-1) that comply with the comparison
dataframe[(dataframe['points'] > 98)][1:3]

# Also could be
dataframe[(dataframe.points > 98)][1:3]
# Out:
#       Unnamed: 0 country                                        description  \
# 1556        1556      US  The flagship wine from Quilceda Creek offers e...
# 1557        1557      US  A stupendous Pinot Noir, showing how beautiful...
#
#                      designation  points  price    province  \
# 1556                         NaN      99  125.0  Washington
# 1557  Precious Mountain Vineyard      99   94.0  California
#
#                   region_1         region_2   taster_name taster_twitter  \
# 1556  Columbia Valley (WA)  Columbia Valley  Paul Gregutt    @paulgwine
# 1557          Sonoma Coast           Sonoma           NaN            NaN
#
#                                                   title             variety  \
# 1556  Quilceda Creek 2008 Cabernet Sauvignon (Columb...  Cabernet Sauvignon
# 1557  Williams Selyem 2009 Precious Mountain Vineyar...          Pinot Noir
#
#                winery
# 1556   Quilceda Creek
# 1557  Williams Selyem

# %%
# Multiple Masking (Filtering)
dataframe[(dataframe['points'] > 98) & (dataframe['country'] == "US")][1:3]
# Out:
#        Unnamed: 0 country                                        description  \
# 1557         1557      US  A stupendous Pinot Noir, showing how beautiful...
# 45798       45798      US  Tasted in a flight of great and famous Napa wi...
#
#                       designation  points  price    province      region_1  \
# 1557   Precious Mountain Vineyard      99   94.0  California  Sonoma Coast
# 45798                         NaN     100  200.0  California   Napa Valley
#
#       region_2 taster_name taster_twitter  \
# 1557    Sonoma         NaN            NaN
# 45798     Napa         NaN            NaN
#
#                                                    title             variety  \
# 1557   Williams Selyem 2009 Precious Mountain Vineyar...          Pinot Noir
# 45798    Cardinale 2006 Cabernet Sauvignon (Napa Valley)  Cabernet Sauvignon
#
#                 winery
# 1557   Williams Selyem
# 45798        Cardinale

# %%
# Applying Filtering and Masking, first by masking and passing to a new dataframe and then indexing
df2 = dataframe[(dataframe['points'] > 98) & (dataframe['country'] == "US")]
df2[['country','price']]
# Out:
#        country  price
# 1556        US  125.0
# 1557        US   94.0
# 45798       US  200.0
# 47428       US   75.0
# 47429       US   75.0
# 47894       US   75.0
# 107901      US  125.0
# 113929      US   80.0
# 116140      US  300.0
# 116141      US  250.0
# 118058      US  450.0
# 118059      US   44.0
# 121884      US  290.0
# 121885      US  150.0
# 123545      US   80.0
# 128265      US  100.0

# %%
# The same done, but in one line, first by masking and then by indexing, and then only showing the 10 first matches
dataframe[(dataframe['points'] > 98) & (dataframe['country'] == "US")][['country','price']][1:11]
# Out:
#        country  price
# 1557        US   94.0
# 45798       US  200.0
# 47428       US   75.0
# 47429       US   75.0
# 47894       US   75.0
# 107901      US  125.0
# 113929      US   80.0
# 116140      US  300.0
# 116141      US  250.0
# 118058      US  450.0

# %% [markdown]
# <a id='104'></a>
# ### Database Operations [↓](#4)

# %%
# To merge to dataframes into one, with the main index value. First we create two datasets with some data and reset the mian index
df1 = dataframe[(dataframe['points'] > 98) & (dataframe['country'] == "US")][['country','price']][1:4]

# To reset the main index from zero, and inplace=True to maintain changes in dataset
df1.reset_index(inplace=True)
df1
# Out:
#    index country  price
# 0   1557      US   94.0
# 1  45798      US  200.0
# 2  47428      US   75.0

# %%
df2 = dataframe[(dataframe['points'] > 98) & (dataframe['country'] == "France")][['country','price']][1:4]

# To reset the main index from zero, and inplace=True to maintain changes in dataframe
df2.reset_index(inplace=True)
df2
# Out:
#    index country  price
# 0  36529  France  800.0
# 1  41835  France  159.0
# 2  58352  France  150.0

# %%
# Concatenate both Dataframes in the same rows (axis = 1) or in the same column (axis = 0)
pd.concat([df1, df2], sort=True, axis=1)
# Out:
#    index country  price  index country  price
# 0   1557      US   94.0  36529  France  800.0
# 1  45798      US  200.0  41835  France  159.0
# 2  47428      US   75.0  58352  France  150.0

# %%
# To Concatenate both Dataframes but without matching the index and adding "NaN" values where there is no information
pd.concat([df1, df2],ignore_index=True,sort=True, axis=1)
# Out:
#        0   1      2      3       4      5
# 0   1557  US   94.0  36529  France  800.0
# 1  45798  US  200.0  41835  France  159.0
# 2  47428  US   75.0  58352  France  150.0

# %%
# To Merge different dataframes, we create three DFs and then we will apply merge with different how options

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Dataframe 1, setting its index in the "Name" Column
df1 = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},{'Name': 'Sally', 'Role': 'Course liasion'},{'Name': 'James', 'Role': 'Grader'}])
df1 = df1.set_index('Name')
df1
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
# Dataframe 2, setting its index in the "Name" Column
df2 = pd.DataFrame([{'Name': 'James', 'School': 'Business'},{'Name': 'Mike', 'School': 'Law'},{'Name': 'Sally', 'School': 'Engineering'}])
df2 = df2.set_index('Name')
df2
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
# Merge with option how='inner'
pd.merge(df1, df2, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# Merge with option how='outer'
pd.merge(df1, df2, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# Merge with option how='left'
pd.merge(df1, df2, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# Merge with option how='right'
pd.merge(df1, df2, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# Merge with no how option (same as inner)
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %% [markdown]
# <a id='105'></a>
# ### Calculations and Aggregations [↓](#5)
# It is used calculations such as sum, mean, median, min, max, count and mode. These must apply in numerical values

# %%
# Sum, mean, median, min and max of a column
dataframe['price'].sum()
# Out:
# 4278086.0

# %%
dataframe['price'].mean()
# Out:
# 35.363389129985535

# %%
dataframe['price'].median()
# Out:
# 25.0

# %%
dataframe['price'].min()
# Out:
# 4.0

# %%
dataframe['price'].max()
# Out:
# 3300.0

# %%
dataframe['price'].count()
# Out:
# 120975

# %%
dataframe['price'].mode()
# Out:
# 0    20.0
# dtype: float64

# %%
# Using GroupBy for object values, we can check the size and do aggrupation of data
dataframe.groupby('country').size()
# Out:
# country
# Argentina                  3800
# Armenia                       2
# Australia                  2329
# Austria                    3345
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      257
# Chile                      4472
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    22093
# Georgia                      86
# Germany                    2165
# Greece                      466
# Hungary                     146
# India                         9
# Israel                      505
# Italy                     19540
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       70
# Moldova                      59
# Morocco                      28
# New Zealand                1419
# Peru                         16
# Portugal                   5691
# Romania                     120
# Serbia                       12
# Slovakia                      1
# Slovenia                     87
# South Africa               1401
# Spain                      6645
# Switzerland                   7
# Turkey                       90
# US                        54504
# Ukraine                      14
# Uruguay                     109
# dtype: int64

# %%
df3 = dataframe.groupby('country').agg({'price':['min', 'median', 'max']})
df3.columns = df3.columns.droplevel(0)
df3.sort_values(by='max',ascending=False)
# Out:
#                          min  median     max
# country
# France                   5.0    25.0  3300.0
# US                       4.0    30.0  2013.0
# Austria                  7.0    25.0  1100.0
# Portugal                 5.0    16.0  1000.0
# Italy                    5.0    28.0   900.0
# Australia                5.0    21.0   850.0
# Germany                  5.0    26.0   775.0
# Spain                    4.0    18.0   770.0
# Hungary                 10.0    25.0   764.0
# Chile                    5.0    15.0   400.0
# South Africa             5.0    19.0   330.0
# Romania                  4.0     9.0   320.0
# Argentina                4.0    17.0   230.0
# Switzerland             21.0    38.0   160.0
# Israel                   8.0    25.0   150.0
# Uruguay                 10.0    20.0   130.0
# New Zealand              7.0    20.0   130.0
# Turkey                  14.0    20.0   120.0
# Canada                  12.0    30.0   120.0
# Mexico                   8.0    22.0   108.0
# Bulgaria                 8.0    13.0   100.0
# England                 25.0    50.0    95.0
# Slovenia                 7.0    20.0    90.0
# Greece                   8.0    19.0    79.0
# Lebanon                 13.0    25.0    75.0
# Peru                    10.0    14.5    68.0
# Croatia                 12.0    20.0    65.0
# Brazil                  10.0    20.0    60.0
# Czech Republic          15.0    18.0    45.0
# Serbia                  15.0    21.0    42.0
# Moldova                  8.0    13.0    42.0
# Georgia                  9.0    17.5    40.0
# Morocco                 14.0    18.0    40.0
# Luxembourg              16.0    23.0    30.0
# Cyprus                  11.0    16.0    21.0
# India                   10.0    12.0    20.0
# Macedonia               15.0    15.0    20.0
# China                   18.0    18.0    18.0
# Slovakia                16.0    16.0    16.0
# Armenia                 14.0    14.5    15.0
# Bosnia and Herzegovina  12.0    12.5    13.0
# Ukraine                  6.0     9.0    13.0
# Egypt                    NaN     NaN     NaN

# %%
dataframe.groupby('country').agg(Minimum=('price','min'), Median=('price','median'), Maximum=('price','max')).sort_values(by='Maximum',ascending=False)
# Out:
#                         Minimum  Median  Maximum
# country
# France                      5.0    25.0   3300.0
# US                          4.0    30.0   2013.0
# Austria                     7.0    25.0   1100.0
# Portugal                    5.0    16.0   1000.0
# Italy                       5.0    28.0    900.0
# Australia                   5.0    21.0    850.0
# Germany                     5.0    26.0    775.0
# Spain                       4.0    18.0    770.0
# Hungary                    10.0    25.0    764.0
# Chile                       5.0    15.0    400.0
# South Africa                5.0    19.0    330.0
# Romania                     4.0     9.0    320.0
# Argentina                   4.0    17.0    230.0
# Switzerland                21.0    38.0    160.0
# Israel                      8.0    25.0    150.0
# Uruguay                    10.0    20.0    130.0
# New Zealand                 7.0    20.0    130.0
# Turkey                     14.0    20.0    120.0
# Canada                     12.0    30.0    120.0
# Mexico                      8.0    22.0    108.0
# Bulgaria                    8.0    13.0    100.0
# England                    25.0    50.0     95.0
# Slovenia                    7.0    20.0     90.0
# Greece                      8.0    19.0     79.0
# Lebanon                    13.0    25.0     75.0
# Peru                       10.0    14.5     68.0
# Croatia                    12.0    20.0     65.0
# Brazil                     10.0    20.0     60.0
# Czech Republic             15.0    18.0     45.0
# Serbia                     15.0    21.0     42.0
# Moldova                     8.0    13.0     42.0
# Georgia                     9.0    17.5     40.0
# Morocco                    14.0    18.0     40.0
# Luxembourg                 16.0    23.0     30.0
# Cyprus                     11.0    16.0     21.0
# India                      10.0    12.0     20.0
# Macedonia                  15.0    15.0     20.0
# China                      18.0    18.0     18.0
# Slovakia                   16.0    16.0     16.0
# Armenia                    14.0    14.5     15.0
# Bosnia and Herzegovina     12.0    12.5     13.0
# Ukraine                     6.0     9.0     13.0
# Egypt                       NaN     NaN      NaN

# %% [markdown]
# <a id='106'></a>
# ### Crosstab [↓](#6)
# This is to compare two values in a table, as a basic Pivot Table, showing only the count of values per each cell

# %%
pd.crosstab(dataframe['country'], dataframe['price'])
# Out:
# price                   4.0     5.0     6.0     7.0     8.0     9.0     \
# country
# Argentina                    1       3      11      19      54      83
# Armenia                      0       0       0       0       0       0
# Australia                    0       4       2      11      38      41
# Austria                      0       0       0       1       0       4
# Bosnia and Herzegovina       0       0       0       0       0       0
# Brazil                       0       0       0       0       0       0
# Bulgaria                     0       0       0       0       5      29
# Canada                       0       0       0       0       0       0
# Chile                        0       4      10      52     123     160
# China                        0       0       0       0       0       0
# Croatia                      0       0       0       0       0       0
# Cyprus                       0       0       0       0       0       0
# Czech Republic               0       0       0       0       0       0
# England                      0       0       0       0       0       0
# France                       0       4       6      25      40     114
# Georgia                      0       0       0       0       0       2
# Germany                      0       1       2       1       3       8
# Greece                       0       0       0       0       3       2
# Hungary                      0       0       0       0       0       0
# India                        0       0       0       0       0       0
# Israel                       0       0       0       0       1       4
# Italy                        0       4       9      19      33      93
# Lebanon                      0       0       0       0       0       0
# Luxembourg                   0       0       0       0       0       0
# Macedonia                    0       0       0       0       0       0
# Mexico                       0       0       0       0       1       0
# Moldova                      0       0       0       0       3      11
# Morocco                      0       0       0       0       0       0
# New Zealand                  0       0       0       1       3       2
# Peru                         0       0       0       0       0       0
# Portugal                     0       8      28     107     176     251
# Romania                      1       0       1      32      12      23
# Serbia                       0       0       0       0       0       0
# Slovakia                     0       0       0       0       0       0
# Slovenia                     0       0       0       3       0       0
# South Africa                 0       1       1       1      11      21
# Spain                        4       4      15      45     133     256
# Switzerland                  0       0       0       0       0       0
# Turkey                       0       0       0       0       0       0
# US                           5      13      30     116     253     230
# Ukraine                      0       0       3       0       0       5
# Uruguay                      0       0       0       0       0       0
#
# price                   10.0    11.0    12.0    13.0    ...  1100.0  1125.0  \
# country                                                 ...
# Argentina                  259     215     311     272  ...       0       0
# Armenia                      0       0       0       0  ...       0       0
# Australia                   76      35      83      95  ...       0       0
# Austria                     27      17      51     118  ...       1       0
# Bosnia and Herzegovina       0       0       1       1  ...       0       0
# Brazil                       1       0       4       0  ...       0       0
# Bulgaria                    11      14       9       3  ...       0       0
# Canada                       0       0       2       2  ...       0       0
# Chile                      388     276     557     313  ...       0       0
# China                        0       0       0       0  ...       0       0
# Croatia                      0       0       1       9  ...       0       0
# Cyprus                       0       1       0       0  ...       0       0
# Czech Republic               0       0       0       0  ...       0       0
# England                      0       0       0       0  ...       0       0
# France                     441     255     672     674  ...       1       1
# Georgia                      5       2       8       5  ...       0       0
# Germany                     34      43      99      56  ...       0       0
# Greece                      12      12      19      28  ...       0       0
# Hungary                      1       1       1       6  ...       0       0
# India                        2       0       4       1  ...       0       0
# Israel                       5       8      17       7  ...       0       0
# Italy                      307     199     350     386  ...       0       0
# Lebanon                      0       0       0       1  ...       0       0
# Luxembourg                   0       0       0       0  ...       0       0
# Macedonia                    0       0       0       0  ...       0       0
# Mexico                       1       4       1       6  ...       0       0
# Moldova                      8       3       2       4  ...       0       0
# Morocco                      0       0       0       0  ...       0       0
# New Zealand                 10      16      19      57  ...       0       0
# Peru                         3       0       0       0  ...       0       0
# Portugal                   422     164     310     287  ...       0       0
# Romania                      9       5       8       0  ...       0       0
# Serbia                       0       0       0       0  ...       0       0
# Slovakia                     0       0       0       0  ...       0       0
# Slovenia                     0       3       5       2  ...       0       0
# South Africa               137      66      68      59  ...       0       0
# Spain                      416     224     359     307  ...       0       0
# Switzerland                  0       0       0       0  ...       0       0
# Turkey                       0       0       0       0  ...       0       0
# US                         857     493     967     843  ...       0       0
# Ukraine                      4       0       0       2  ...       0       0
# Uruguay                      3       1       4       4  ...       0       0
#
# price                   1200.0  1300.0  1500.0  1900.0  2000.0  2013.0  \
# country
# Argentina                    0       0       0       0       0       0
# Armenia                      0       0       0       0       0       0
# Australia                    0       0       0       0       0       0
# Austria                      0       0       0       0       0       0
# Bosnia and Herzegovina       0       0       0       0       0       0
# Brazil                       0       0       0       0       0       0
# Bulgaria                     0       0       0       0       0       0
# Canada                       0       0       0       0       0       0
# Chile                        0       0       0       0       0       0
# China                        0       0       0       0       0       0
# Croatia                      0       0       0       0       0       0
# Cyprus                       0       0       0       0       0       0
# Czech Republic               0       0       0       0       0       0
# England                      0       0       0       0       0       0
# France                       1       1       2       1       2       0
# Georgia                      0       0       0       0       0       0
# Germany                      0       0       0       0       0       0
# Greece                       0       0       0       0       0       0
# Hungary                      0       0       0       0       0       0
# India                        0       0       0       0       0       0
# Israel                       0       0       0       0       0       0
# Italy                        0       0       0       0       0       0
# Lebanon                      0       0       0       0       0       0
# Luxembourg                   0       0       0       0       0       0
# Macedonia                    0       0       0       0       0       0
# Mexico                       0       0       0       0       0       0
# Moldova                      0       0       0       0       0       0
# Morocco                      0       0       0       0       0       0
# New Zealand                  0       0       0       0       0       0
# Peru                         0       0       0       0       0       0
# Portugal                     0       0       0       0       0       0
# Romania                      0       0       0       0       0       0
# Serbia                       0       0       0       0       0       0
# Slovakia                     0       0       0       0       0       0
# Slovenia                     0       0       0       0       0       0
# South Africa                 0       0       0       0       0       0
# Spain                        0       0       0       0       0       0
# Switzerland                  0       0       0       0       0       0
# Turkey                       0       0       0       0       0       0
# US                           0       0       0       0       0       1
# Ukraine                      0       0       0       0       0       0
# Uruguay                      0       0       0       0       0       0
#
# price                   2500.0  3300.0
# country
# Argentina                    0       0
# Armenia                      0       0
# Australia                    0       0
# Austria                      0       0
# Bosnia and Herzegovina       0       0
# Brazil                       0       0
# Bulgaria                     0       0
# Canada                       0       0
# Chile                        0       0
# China                        0       0
# Croatia                      0       0
# Cyprus                       0       0
# Czech Republic               0       0
# England                      0       0
# France                       2       1
# Georgia                      0       0
# Germany                      0       0
# Greece                       0       0
# Hungary                      0       0
# India                        0       0
# Israel                       0       0
# Italy                        0       0
# Lebanon                      0       0
# Luxembourg                   0       0
# Macedonia                    0       0
# Mexico                       0       0
# Moldova                      0       0
# Morocco                      0       0
# New Zealand                  0       0
# Peru                         0       0
# Portugal                     0       0
# Romania                      0       0
# Serbia                       0       0
# Slovakia                     0       0
# Slovenia                     0       0
# South Africa                 0       0
# Spain                        0       0
# Switzerland                  0       0
# Turkey                       0       0
# US                           0       0
# Ukraine                      0       0
# Uruguay                      0       0
#
# [42 rows x 390 columns]

# %% [markdown]
# <a id='107'></a>
# ### Pivot [↓](7)
# It takes urther the analysis by adding specific calcultations into a crossed table.

# %%
dataframe.pivot_table(values='price', index='country', columns='points', aggfunc=np.mean)
# Out:
# points                        80         81         82         83         84   \
# country
# Argentina               13.631579  13.489362  14.129252  14.871429  14.581281
# Armenia                       NaN        NaN        NaN        NaN        NaN
# Australia               12.000000  14.125000  19.368421  13.750000  16.871795
# Austria                       NaN        NaN  13.250000  19.571429  15.272727
# Bosnia and Herzegovina        NaN        NaN        NaN        NaN        NaN
# Brazil                  20.000000  25.500000  16.000000  26.400000  18.333333
# Bulgaria                 9.000000        NaN   9.000000   9.333333  10.500000
# Canada                        NaN        NaN  19.000000  16.000000  45.750000
# Chile                   13.220000  13.237500  12.700637  13.299296  13.532151
# China                         NaN        NaN        NaN        NaN        NaN
# Croatia                       NaN  18.000000  40.500000  20.000000  13.500000
# Cyprus                        NaN        NaN        NaN        NaN        NaN
# Czech Republic                NaN        NaN        NaN        NaN  16.000000
# England                       NaN        NaN        NaN        NaN        NaN
# France                  15.866667  13.400000  16.283951  17.237705  17.578366
# Georgia                       NaN        NaN  30.000000  16.333333  23.500000
# Germany                       NaN  76.000000  14.000000  13.000000  20.294118
# Greece                        NaN        NaN  17.250000  20.000000  17.809524
# Hungary                       NaN  20.000000        NaN  21.500000  75.000000
# India                         NaN        NaN        NaN        NaN        NaN
# Israel                  19.000000  24.000000  18.000000  19.500000  21.285714
# Italy                   11.000000  20.600000  17.315789  17.369048  17.130621
# Lebanon                       NaN        NaN  14.500000  28.000000  19.000000
# Luxembourg                    NaN        NaN        NaN        NaN        NaN
# Macedonia                     NaN        NaN        NaN        NaN  15.500000
# Mexico                  14.000000  11.000000  18.888889  20.555556  26.750000
# Moldova                       NaN        NaN  10.000000  11.250000  11.000000
# Morocco                       NaN        NaN        NaN        NaN        NaN
# New Zealand             16.000000  15.000000  17.000000  20.214286  17.953488
# Peru                    15.000000  12.000000  12.000000  10.000000  16.250000
# Portugal                 8.000000  11.181818  12.888889  10.205882  12.264026
# Romania                       NaN        NaN   9.000000  10.000000  11.222222
# Serbia                        NaN        NaN        NaN        NaN        NaN
# Slovakia                      NaN        NaN        NaN        NaN        NaN
# Slovenia                      NaN        NaN  15.000000  20.000000  20.000000
# South Africa                  NaN        NaN  13.800000  10.500000  12.984375
# Spain                   13.820513  16.771739  15.325472  15.674352  15.913934
# Switzerland                   NaN        NaN        NaN  38.000000        NaN
# Turkey                        NaN        NaN        NaN        NaN  18.200000
# US                      20.363057  19.647239  21.891650  21.888804  23.672666
# Ukraine                       NaN        NaN  10.000000  11.000000   8.000000
# Uruguay                 13.000000  16.000000  14.200000  16.500000  25.090909
#
# points                        85         86         87         88   \
# country
# Argentina               14.932692  16.110577  19.318280  20.907455
# Armenia                       NaN        NaN  14.000000  15.000000
# Australia               15.625767  18.381503  21.929577  24.124514
# Austria                 18.190476  18.104762  20.087209  20.930556
# Bosnia and Herzegovina  13.000000        NaN        NaN  12.000000
# Brazil                  21.111111  29.111111  22.000000  24.800000
# Bulgaria                 8.857143  11.071429  11.650000  13.615385
# Canada                  30.428571  27.272727  24.566667  26.531250
# Chile                   13.507853  14.272727  16.818584  21.007984
# China                         NaN        NaN        NaN        NaN
# Croatia                 23.000000  18.500000  19.642857  22.166667
# Cyprus                  16.333333        NaN  14.666667  14.000000
# Czech Republic          21.500000        NaN  15.000000  18.000000
# England                       NaN        NaN        NaN        NaN
# France                  17.720946  19.674405  23.626741  28.573328
# Georgia                 12.000000  12.333333  16.722222  18.352941
# Germany                 21.913043  19.017391  22.807107  22.272727
# Greece                  21.354167  20.677966  23.275862  24.696203
# Hungary                 22.000000  24.750000  20.090909  22.588235
# India                         NaN        NaN  12.000000        NaN
# Israel                  22.638889  24.185185  28.184211  28.542373
# Italy                   20.020899  22.384132  25.912896  31.896667
# Lebanon                 45.000000  20.000000  29.000000  23.111111
# Luxembourg                    NaN        NaN        NaN  25.333333
# Macedonia               15.000000  16.000000  15.000000  15.000000
# Mexico                  29.000000  22.800000  25.583333  27.111111
# Moldova                 10.000000   9.500000  13.250000  18.333333
# Morocco                 14.000000  30.000000  16.000000  17.625000
# New Zealand             18.302752  19.980392  20.594059  22.207254
# Peru                    28.500000  18.500000        NaN        NaN
# Portugal                12.375472  13.865672  17.033784  19.165179
# Romania                 23.045455   8.947368   9.500000  19.647059
# Serbia                        NaN  18.500000  21.000000  18.000000
# Slovakia                      NaN        NaN  16.000000        NaN
# Slovenia                13.500000  15.833333  18.823529  21.428571
# South Africa            14.379845  15.128205  18.329004  21.027933
# Spain                   16.411765  17.015019  19.676889  24.390156
# Switzerland                   NaN        NaN        NaN        NaN
# Turkey                  19.000000  27.384615  20.588235  18.833333
# US                      24.452959  26.975122  28.390665  31.263256
# Ukraine                  9.000000   9.000000        NaN   9.000000
# Uruguay                 19.200000  20.666667  24.608696  28.250000
#
# points                         89   ...        91         92         93   \
# country                             ...
# Argentina                28.541806  ...  47.874396  57.727778  80.087500
# Armenia                        NaN  ...        NaN        NaN        NaN
# Australia                30.011538  ...  44.673077  50.918129  69.544554
# Austria                  24.731527  ...  29.842818  36.658854  41.380165
# Bosnia and Herzegovina         NaN  ...        NaN        NaN        NaN
# Brazil                   40.500000  ...        NaN        NaN        NaN
# Bulgaria                 15.720930  ...  33.250000        NaN        NaN
# Canada                   41.172414  ...  44.232558  42.352941  45.142857
# Chile                    25.667692  ...  44.113514  65.212389  88.792453
# China                    18.000000  ...        NaN        NaN        NaN
# Croatia                  37.100000  ...  46.666667        NaN        NaN
# Cyprus                   19.333333  ...        NaN        NaN        NaN
# Czech Republic           43.333333  ...        NaN        NaN        NaN
# England                  43.461538  ...  50.733333  46.000000  60.750000
# France                   32.794425  ...  43.379093  54.762934  74.983152
# Georgia                  21.333333  ...        NaN  25.000000        NaN
# Germany                  26.858553  ...  38.015444  48.318408  67.101190
# Greece                   21.672414  ...  25.571429  23.866667  25.500000
# Hungary                  30.000000  ...  44.166667  68.375000  31.600000
# India                    12.000000  ...  12.000000  19.000000  20.000000
# Israel                   28.417910  ...  43.566667  41.093750  36.636364
# Italy                    38.506278  ...  51.888700  61.075024  73.800776
# Lebanon                  21.250000  ...  39.571429        NaN        NaN
# Luxembourg               21.000000  ...        NaN        NaN        NaN
# Macedonia                17.500000  ...        NaN        NaN        NaN
# Mexico                   31.000000  ...  76.500000  54.000000        NaN
# Moldova                  19.000000  ...  25.000000        NaN        NaN
# Morocco                  19.000000  ...  19.500000        NaN  18.000000
# New Zealand              26.860465  ...  38.099291  43.666667  55.125000
# Peru                           NaN  ...        NaN        NaN        NaN
# Portugal                 21.401198  ...  30.907143  37.667614  56.168000
# Romania                  19.555556  ...        NaN  28.000000        NaN
# Serbia                   35.500000  ...        NaN        NaN        NaN
# Slovakia                       NaN  ...        NaN        NaN        NaN
# Slovenia                 28.272727  ...  50.000000  50.000000        NaN
# South Africa             24.441860  ...  41.180000  50.061224  85.687500
# Spain                    30.123539  ...  42.921320  55.779661  81.518293
# Switzerland             160.000000  ...        NaN        NaN        NaN
# Turkey                   25.294118  ...  36.000000  36.000000        NaN
# US                       32.909215  ...  43.375473  49.461931  56.614642
# Ukraine                        NaN  ...        NaN        NaN        NaN
# Uruguay                  29.666667  ...  37.166667  43.000000        NaN
#
# points                         94          95          96          97   \
# country
# Argentina                82.209302   87.375000   49.000000  120.000000
# Armenia                        NaN         NaN         NaN         NaN
# Australia                93.604167  142.960000  233.545455  140.000000
# Austria                  59.232394   60.567568   72.833333  101.600000
# Bosnia and Herzegovina         NaN         NaN         NaN         NaN
# Brazil                         NaN         NaN         NaN         NaN
# Bulgaria                       NaN         NaN         NaN         NaN
# Canada                   48.333333         NaN         NaN         NaN
# Chile                    76.166667   80.000000         NaN         NaN
# China                          NaN         NaN         NaN         NaN
# Croatia                        NaN         NaN         NaN         NaN
# Cyprus                         NaN         NaN         NaN         NaN
# Czech Republic                 NaN         NaN         NaN         NaN
# England                  54.181818   66.666667         NaN         NaN
# France                  106.444790  168.904321  295.190909  363.380000
# Georgia                        NaN         NaN         NaN         NaN
# Germany                  96.585106  166.216216  248.647059  464.714286
# Greece                         NaN         NaN         NaN         NaN
# Hungary                 320.000000   43.000000  166.333333   80.000000
# India                          NaN         NaN         NaN         NaN
# Israel                   25.000000         NaN         NaN         NaN
# Italy                    88.404977  113.223350  141.806452  169.476190
# Lebanon                        NaN         NaN         NaN         NaN
# Luxembourg                     NaN         NaN         NaN         NaN
# Macedonia                      NaN         NaN         NaN         NaN
# Mexico                         NaN         NaN         NaN         NaN
# Moldova                        NaN         NaN         NaN         NaN
# Morocco                        NaN         NaN         NaN         NaN
# New Zealand              60.333333   89.500000         NaN         NaN
# Peru                           NaN         NaN         NaN         NaN
# Portugal                 77.385246  118.967213  149.000000  188.916667
# Romania                        NaN         NaN         NaN         NaN
# Serbia                         NaN         NaN         NaN         NaN
# Slovakia                       NaN         NaN         NaN         NaN
# Slovenia                       NaN         NaN         NaN         NaN
# South Africa             68.666667  183.333333         NaN         NaN
# Spain                   114.712500  142.965517  179.125000  179.000000
# Switzerland                    NaN         NaN         NaN         NaN
# Turkey                         NaN         NaN         NaN         NaN
# US                       70.190742   76.742188   95.588235  124.135802
# Ukraine                        NaN         NaN         NaN         NaN
# Uruguay                        NaN         NaN         NaN         NaN
#
# points                         98          99       100
# country
# Argentina                      NaN         NaN      NaN
# Armenia                        NaN         NaN      NaN
# Australia               309.200000  575.000000  350.000
# Austria                        NaN         NaN      NaN
# Bosnia and Herzegovina         NaN         NaN      NaN
# Brazil                         NaN         NaN      NaN
# Bulgaria                       NaN         NaN      NaN
# Canada                         NaN         NaN      NaN
# Chile                          NaN         NaN      NaN
# China                          NaN         NaN      NaN
# Croatia                        NaN         NaN      NaN
# Cyprus                         NaN         NaN      NaN
# Czech Republic                 NaN         NaN      NaN
# England                        NaN         NaN      NaN
# France                  449.428571  506.333333  685.375
# Georgia                        NaN         NaN      NaN
# Germany                 775.000000         NaN      NaN
# Greece                         NaN         NaN      NaN
# Hungary                        NaN         NaN      NaN
# India                          NaN         NaN      NaN
# Israel                         NaN         NaN      NaN
# Italy                   153.000000  321.333333  372.500
# Lebanon                        NaN         NaN      NaN
# Luxembourg                     NaN         NaN      NaN
# Macedonia                      NaN         NaN      NaN
# Mexico                         NaN         NaN      NaN
# Moldova                        NaN         NaN      NaN
# Morocco                        NaN         NaN      NaN
# New Zealand                    NaN         NaN      NaN
# Peru                           NaN         NaN      NaN
# Portugal                317.333333  347.000000  550.000
# Romania                        NaN         NaN      NaN
# Serbia                         NaN         NaN      NaN
# Slovakia                       NaN         NaN      NaN
# Slovenia                       NaN         NaN      NaN
# South Africa                   NaN         NaN      NaN
# Spain                   450.000000         NaN      NaN
# Switzerland                    NaN         NaN      NaN
# Turkey                         NaN         NaN      NaN
# US                      154.181818  141.916667  202.500
# Ukraine                        NaN         NaN      NaN
# Uruguay                        NaN         NaN      NaN
#
# [42 rows x 21 columns]

# %% [markdown]
# <a id='108'></a>
# ### Date Transformation [↓](#8)
# To change Dates in date format for python

# %%
date = "1949 January"
new_date = pd.to_datetime(date)
print(new_date)
# Out:
# 1949-01-01 00:00:00

# %% [markdown]
# # Short Cheat Sheet

# %% [markdown]
# <a id='1'></a>[↑](#101)
# **COMMANDS**
# #Install Pandas
# * !pip install pandas
#
# #Import Pandas and NumPy
# * import pandas as pd
# * import numpy as np
#
# #Get info on a command
# * ?dataframe.index
#
# #Read File
# * dataframe = pd.read_csv("file_folder_and_name")
#
# #Set index and reset index on Dataframe
# * dataframe = dataframe.set_index("Header_For_Index")
# * dataframe = dataframe.reset_index()
#
# #General Commands, Columns names and number of index (rows)
# * dataframe.head(N)
# * dataframe.tail(N)
# * dataframe.info()
# * dataframe.dtypes
# * dataframe.shape
# * dataframe.columns
# * dataframe.index
# * dataframe.describe()
# * dataframe.describe(include = ['O']) # Summary of object columns
# * dataframe.unique()
# * dataframe.nunique()
# * dataframe.isnull().sum() # Show number of null values per column
# * dataframe['Header_1'].value_counts() # Count of repeted events
# * dataframe['Header_1'].value_counts(dropna=False) #Count all values including null values
# * dataframe = dataframe.rename(columns={'Header_1':'New_Header_1'})
#
# <a id='2'></a>[↑](#102)
# #Indexers loc and iloc
#
# <a id='3'></a>[↑](#103)
# #Simple Indexing
# * dataframe[[ 'Header_1', 'Header_3',..., 'Header_X' ]][ first_row : last_row-1 ]
#
# <a id='4'></a>[↑](#104)
# #Masking (Filtering)
# * dataframe[ (dataframe['Header_X'] **operator / conditional**) ][ first_row : last_row-1 ]
# * dataframe[ (dataframe.Header_X **operator / conditional**) ][ first_row : last_row-1 ]
#
# #Advanced Masking and Filtering
# * dataframe[(dataframe.Header_X **operator / conditional**) **conditional** (dataframe.Header_Y **operator / conditional**) **conditional** ... ][[Header_X, Header_Y, Header_Z, ... ]][[ first_row : last_row-1 ]
#
# #Concatenate both Dataframes in the same rows (axis = 1) or in the same column (axis = 0); Use option **ignore_index=True** to ignore matching index
# * pd.concat([dataframe_1, dataframe_2], sort=True, axis=1)
#
# #Merge with options how='inner', 'outer', 'left', 'right', and mergin with specific Headers between Dataframes
# * pd.merge(dataframe_1, dataframe_2, how='**option**', left_index=True, right_index=True)
# * pd.merge(dataframe_1, dataframe_2, how='**option**','left_on=['Header_1','Header_3'], right_on=['Header_1','Header_3'])
#
# <a id='5'></a>[↑](#105)
# #Basic Statistical Calculations: sum, mean, median, mode, count, min, max
# * dataframe['Header_1'].**calculation**()
#
# #GroupBy Header and Aggregate vs. Statistical info
# * dataframe.groupby('Header_1').size()
# * dataframe.groupby('Header_1').agg({'Header_2':['min', 'max', ...]'})
#
# #Groupby Header_1, aggreagate and sort
# * dataframe = dataframe.groupby('Header_1').agg({'Header_2':['min', 'median', 'max']})
# * dataframe.columns = dataframe.columns.droplevel(0)
# * dataframe.sort_values(by='max',ascending=False)
#
# or
#
# * dataframe = dataframe.groupby('Header_1').agg(Minimum=('Header_2','min'), Median=('Header_2','median'), Maximum=('Header_2','max')).sort_values(by='Maximum',ascending=False)
#
# <a id='6'></a>[↑](#106)
# #Crosstab
# * pd.crosstab(dataframe['Header_1'], dataframe['Header_2'])
#
# <a id='7'></a>[↑](#107)
# #Pivot
# * dataframe.pivot_table(values='Header_1_in_Calculation', index='Header_2_in_axis_X', columns='Header_3_in_axis_Y', aggfunc=np.**calculation**)
#
# <a id='8'></a>[↑](#108)
# #Date Transformation to yyyy-mm-dd
# * dataframe['Column_Date'] = pd.to_datetime(dataframe['Column_2_Date'])
